# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
import warnings
warnings.simplefilter('ignore')

# %%
# Load dataset
df = pd.read_csv('Life Expectancy Data.csv')
#df.dataframeName = 'Life Expectancy Data.csv'
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df = df.drop(['Country','Year','Status'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Life expectancy                  2928 non-null   float64
#  1   Adult Mortality                  2928 non-null   float64
#  2   infant deaths                    2938 non-null   int64
#  3   Alcohol                          2744 non-null   float64
#  4   percentage expenditure           2938 non-null   float64
#  5   Hepatitis B                      2385 non-null   float64
#  6   Measles                          2938 non-null   int64
#  7    BMI                             2904 non-null   float64
#  8   under-five deaths                2938 non-null   int64
#  9   Polio                            2919 non-null   float64
#  10  Total expenditure                2712 non-null   float64
#  11  Diphtheria                       2919 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Life expectancy   Adult Mortality  infant deaths      Alcohol  \
# count       2928.000000      2928.000000    2938.000000  2744.000000
# mean          69.224932       164.796448      30.303948     4.602861
# std            9.523867       124.292079     117.926501     4.052413
# min           36.300000         1.000000       0.000000     0.010000
# 25%           63.100000        74.000000       0.000000     0.877500
# 50%           72.100000       144.000000       3.000000     3.755000
# 75%           75.700000       228.000000      22.000000     7.702500
# max           89.000000       723.000000    1800.000000    17.870000
#
#        percentage expenditure  Hepatitis B       Measles          BMI   \
# count             2938.000000  2385.000000    2938.000000  2904.000000
# mean               738.251295    80.940461    2419.592240    38.321247
# std               1987.914858    25.070016   11467.272489    20.044034
# ...

# %%
df.isnull().sum()
# Out:
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (1649, 19)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0              65.0            263.0             62     0.01
# 1              59.9            271.0             64     0.01
# 2              59.9            268.0             66     0.01
# 3              59.5            272.0             69     0.01
# 4              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
corr_matrix = abs(df.corr())
print(corr_matrix["Life expectancy "].sort_values(ascending=False))
# Out:
# Life expectancy                    1.000000
# Schooling                          0.727630
# Income composition of resources    0.721083
# Adult Mortality                    0.702523
#  HIV/AIDS                          0.592236
#  BMI                               0.542042
#  thinness  1-19 years              0.457838
#  thinness 5-9 years                0.457508
# GDP                                0.441322
# percentage expenditure             0.409631
# Alcohol                            0.402718
# Diphtheria                         0.341331
# Polio                              0.327294
# Hepatitis B                        0.199935
# under-five deaths                  0.192265
# Total expenditure                  0.174718
# infant deaths                      0.169074
# Measles                            0.068881
# Population                         0.022305
# Name: Life expectancy , dtype: float64

# %%
X = df.drop(['Life expectancy ','Population','GDP','percentage expenditure','Total expenditure',' thinness 5-9 years'],axis=1)
y = df['Life expectancy ']

# %%
X.shape
# Out:
# (1649, 13)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=45)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=500)
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
y_pred = rfr.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 3.6486782233535178

# %%
X_train
# Out:
#       Adult Mortality  infant deaths  Alcohol  Hepatitis B  Measles    BMI   \
# 1612             93.0              0     1.47         98.0      1395   18.0
# 2832            183.0             21     2.56         98.0         0    4.0
# 1873            198.0              4     3.77         86.0         0   44.9
# 979             125.0              1     6.13         91.0      3188   55.3
# 2915            526.0             33     2.25         81.0       459   18.8
# ...               ...            ...      ...          ...       ...    ...
# 257             177.0              0     6.58         95.0         0    5.1
# 1040             83.0              1     8.62          9.0        12   58.0
# 2733             25.0              5     8.44         46.0     12746   59.6
# 675              54.0              0     9.04         96.0         0   59.2
# 1658            217.0              8     0.02         74.0         4   26.1
#
# ...

# %%
pred_test = rfr.predict( [[263.0, #Adult Mortality
                          62, #infant deaths
                          0.01, #Alcohol
                          65.0, #Hepatitis B
                          1154, #Measles
                          19.1, #BMI
                          83, #under-five deaths
                          6.0, # Polio
                          65.0, #Diphtheria
                          0.1, #HIV/AIDS
                          17.3, #thinness 1-19 years
                          0.479 , #Income composition of resources
                          10.1  #Schooling
                         ]])

# %%
pred_test[0].round(2)
# Out:
# 60.63

# %%
# Creating a pickle file for the classifier use randomforest classifier
import pickle
filename = 'life_expectancy.pkl'
pickle.dump(rfr, open(filename, 'wb'))

# %%
filename = 'life_expectancy.pkl'
rfr = pickle.load(open(filename, 'rb'))

# %%
pred_test = rfr.predict([[263.0,
                          62,
                          0.01,
                          65.0,
                          1154,
                          19.1,
                          83,
                          6.0,
                          65,
                          0.1,
                          17.3,
                          0.479,
                          10.1 ]])

# %%
pred_test[0] .round(2)
# Out:
# 60.63
